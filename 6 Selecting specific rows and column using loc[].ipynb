# %%
import pandas as pd
df="D:\student_info.csv"
Data=pd.read_csv(df,index_col=0)
Result=Data.loc["S45":"S65",]
Result
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Naga-Meena-Sabari\AppData\Local\Temp\ipykernel_6796\380692023.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df="D:\student_info.csv"
#                   name  gender  age  grade_level  math_score  reading_score  \
# student_id
# S45         Student_45    Male   16           12          96             94
# S46         Student_46   Other   16           12          67             66
# S47         Student_47  Female   16           10          70             66
# S48         Student_48    Male   15           12          62             98
# S49         Student_49  Female   17           12          70             82
# S50         Student_50  Female   16           12          57             81
# S51         Student_51  Female   16           10          95             57
# S52         Student_52    Male   15            9          89             68
# ...

# %%
Result=Data.loc["S45":"S65",["grade_level","attendance_rate","final_result"]]
Result
# Out:
#             grade_level  attendance_rate final_result
# student_id
# S45                  12        96.471045         Pass
# S46                  12        96.413923         Fail
# S47                  10        89.547008         Fail
# S48                  12        87.016382         Fail
# S49                  12        87.251196         Pass
# S50                  12        96.114291         Pass
# S51                  10        86.563590         Fail
# S52                   9        84.181187         Pass
# S53                  11        81.693767         Fail
# S54                  12        89.333862         Pass
# S55                   9        89.642642         Fail
# S56                  12        96.818174         Pass
# S57                  10        84.424774         Fail
# S58                   9        87.619825         Pass
# S59                  10        96.168115         Pass
# S60                  12        96.472472         Fail
# ...
