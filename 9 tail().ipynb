# %%
import pandas as pd
df=pd.read_csv("D:\student_info.csv")
df.tail()   # By default tail() prints last 5 rows
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Naga-Meena-Sabari\AppData\Local\Temp\ipykernel_8840\1025481955.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv("D:\student_info.csv")
#     student_id          name  gender  age  grade_level  math_score  \
# 995       S996   Student_996  Female   15           10          76
# 996       S997   Student_997  Female   17           12          83
# 997       S998   Student_998   Other   16           10          60
# 998       S999   Student_999   Other   17            9          94
# 999      S1000  Student_1000    Male   17            9          96
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 995             75             55        94.127440       Bachelor's
# 996             68             98        86.911592       Bachelor's
# 997             77             92        80.139645              PhD
# ...

# %%
df.tail(20)   # print last 20 rows
# Out:
#     student_id          name  gender  age  grade_level  math_score  \
# 980       S981   Student_981   Other   16           12          67
# 981       S982   Student_982    Male   16           12          89
# 982       S983   Student_983  Female   16            9          71
# 983       S984   Student_984    Male   17           11          73
# 984       S985   Student_985    Male   17           12          68
# 985       S986   Student_986    Male   17           12          86
# 986       S987   Student_987    Male   15           12          88
# 987       S988   Student_988  Female   16            9          70
# 988       S989   Student_989    Male   16            9          57
# 989       S990   Student_990  Female   17           10          77
# 990       S991   Student_991  Female   16           11          54
# 991       S992   Student_992   Other   16           10          66
# 992       S993   Student_993  Female   17           11          86
# ...
