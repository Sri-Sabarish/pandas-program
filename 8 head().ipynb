# %%
import pandas as pd
df=pd.read_csv("D:\student_info.csv",index_col=0)
df.head() # By default head() prints first 5 rows
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Naga-Meena-Sabari\AppData\Local\Temp\ipykernel_5528\1251434170.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv("D:\student_info.csv",index_col=0)
#                  name gender  age  grade_level  math_score  reading_score  \
# student_id
# S1          Student_1  Other   17           10          74             61
# S2          Student_2   Male   17           12          99             70
# S3          Student_3  Other   17            9          59             60
# S4          Student_4  Other   17           12          70             88
# S5          Student_5   Male   15            9          85             77
#
#             writing_score  attendance_rate parent_education  study_hours  \
# student_id
# S1                     90        94.660002         Master's     4.120192
# S2                     91        93.173227       Bachelor's     2.886505
# ...

# %%
df.head(20) # prints first 20 rows
# Out:
#                   name  gender  age  grade_level  math_score  reading_score  \
# student_id
# S1           Student_1   Other   17           10          74             61
# S2           Student_2    Male   17           12          99             70
# S3           Student_3   Other   17            9          59             60
# S4           Student_4   Other   17           12          70             88
# S5           Student_5    Male   15            9          85             77
# S6           Student_6    Male   17           11          61             54
# S7           Student_7   Other   16            9          76             66
# S8           Student_8  Female   16           11          89             69
# S9           Student_9   Other   17           12          51             90
# S10         Student_10   Other   17           11          62             95
# S11         Student_11   Other   16           12          81             61
# ...
